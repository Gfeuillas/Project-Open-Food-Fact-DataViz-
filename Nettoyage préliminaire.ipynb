# %%
import pandas as pd
import numpy as np
import openfoodfacts as off
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
products = pd.read_csv("./en.openfoodfacts.org.products.csv", error_bad_lines=False,sep="\t")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (0,19,20,24,25,26,28,49,61) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
products.describe()
# Out:
#           created_t  last_modified_t  cities  allergens_en  serving_quantity  \
# count  1.457517e+06     1.457517e+06     0.0           0.0      4.419920e+05
# mean   1.538897e+09     1.572966e+09     NaN           NaN      2.513872e+16
# std    4.608371e+07     2.605768e+07     NaN           NaN      1.671284e+19
# min    1.328021e+09     1.333873e+09     NaN           NaN      0.000000e+00
# 25%    1.508598e+09     1.563901e+09     NaN           NaN      2.800000e+01
# 50%    1.547782e+09     1.582754e+09     NaN           NaN      5.000000e+01
# 75%    1.578011e+09     1.587666e+09     NaN           NaN      1.130000e+02
# max    1.599527e+09     1.599528e+09     NaN           NaN      1.111111e+22
#
#        no_nutriments    additives_n  additives  ingredients_from_palm_oil_n  \
# count            0.0  643031.000000        0.0                643031.000000
# mean             NaN       2.008819        NaN                     0.020811
# ...

# %%
products.head()
# Out:
#                    code                                                url  \
# 0         0000000000017  http://world-en.openfoodfacts.org/product/0000...
# 1         0000000000031  http://world-en.openfoodfacts.org/product/0000...
# 2    000000000003327986  http://world-en.openfoodfacts.org/product/0000...
# 3         0000000000100  http://world-en.openfoodfacts.org/product/0000...
# 4  00000000001111111111  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0                     kiliweb  1529059080  2018-06-15T10:38:00Z
# 1                    isagoofy  1539464774  2018-10-13T21:06:14Z
# 2                     kiliweb  1574175736  2019-11-19T15:02:16Z
# 3                       del51  1444572561  2015-10-11T14:09:21Z
# 4  openfoodfacts-contributors  1560020173  2019-06-08T18:56:13Z
#
#    last_modified_t last_modified_datetime                  product_name  \
# ...

# %%
products.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'carbon-footprint-from-meat-or-fish_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g', 'water-hardness_100g',
#        'choline_100g', 'phylloquinone_100g', 'beta-glucan_100g',
#        'inositol_100g', 'carnitine_100g'],
#       dtype='object', length=181)

# %%
french1= products.loc[products["countries"]=="France"]

# %%
french1
# Out:
#                   code                                                url  \
# 0        0000000000017  http://world-en.openfoodfacts.org/product/0000...
# 1        0000000000031  http://world-en.openfoodfacts.org/product/0000...
# 3        0000000000100  http://world-en.openfoodfacts.org/product/0000...
# 5        0000000000123  http://world-en.openfoodfacts.org/product/0000...
# 6        0000000000178  http://world-en.openfoodfacts.org/product/0000...
# ...                ...                                                ...
# 1457502  9999991042728  http://world-en.openfoodfacts.org/product/9999...
# 1457503  9999991042742  http://world-en.openfoodfacts.org/product/9999...
# 1457505  9999991149090  http://world-en.openfoodfacts.org/product/9999...
# 1457509  9999999004360  http://world-en.openfoodfacts.org/product/9999...
# 1457511       99999995  http://world-en.openfoodfacts.org/product/9999...
#
#           creator   created_t      created_datetime  last_modified_t  \
# ...

# %%
french= products.loc[products['countries'].str.contains('fr',na=False, case=False)]
pd.export_csv

# %%
french
# Out:
#                          code  \
# 0               0000000000017
# 1               0000000000031
# 3               0000000000100
# 4        00000000001111111111
# 5               0000000000123
# ...                       ...
# 1457506         9999992756068
# 1457507              99999988
# 1457509         9999999004360
# 1457511              99999995
# 1457516       999999999999999
#
#                                                        url  \
# 0        http://world-en.openfoodfacts.org/product/0000...
# 1        http://world-en.openfoodfacts.org/product/0000...
# 3        http://world-en.openfoodfacts.org/product/0000...
# 4        http://world-en.openfoodfacts.org/product/0000...
# 5        http://world-en.openfoodfacts.org/product/0000...
# ...                                                    ...
# 1457506  http://world-en.openfoodfacts.org/product/9999...
# 1457507  http://world-en.openfoodfacts.org/product/9999...
# ...

# %%
#pourcentage de valeurs non-null
percent= 0.20
#calcul du Threshold (Nombre de valeurs réel)
tresh= len(french)*percent
french2= french.dropna(axis=1,thresh=tresh, subset=None, inplace=False)

# %%
french2
# Out:
#                          code  \
# 0               0000000000017
# 1               0000000000031
# 3               0000000000100
# 4        00000000001111111111
# 5               0000000000123
# ...                       ...
# 1457506         9999992756068
# 1457507              99999988
# 1457509         9999999004360
# 1457511              99999995
# 1457516       999999999999999
#
#                                                        url  \
# 0        http://world-en.openfoodfacts.org/product/0000...
# 1        http://world-en.openfoodfacts.org/product/0000...
# 3        http://world-en.openfoodfacts.org/product/0000...
# 4        http://world-en.openfoodfacts.org/product/0000...
# 5        http://world-en.openfoodfacts.org/product/0000...
# ...                                                    ...
# 1457506  http://world-en.openfoodfacts.org/product/9999...
# 1457507  http://world-en.openfoodfacts.org/product/9999...
# ...

# %%
french2.to_csv('./french.csv',index=False)
